# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel (r'C:\Users\Jithu\Downloads\salesdata.xlsx')
df.describe()
# Out:
#              ID       sales       type
# count  15.000000  12.000000  14.000000
# mean    8.000000  42.083333   1.500000
# std     4.472136  27.720876   0.518875
# min     1.000000  10.000000   1.000000
# 25%     4.500000  21.750000   1.000000
# 50%     8.000000  38.500000   1.500000
# 75%    11.500000  58.250000   2.000000
# max    15.000000  98.000000   2.000000

# %%
df.shape
# rows and columns in file
# Out:
# (15, 5)

# %%
df.dtypes
#datatypes of columns
# Out:
# ID             int64
# product       object
# sales        float64
# type         float64
# available     object
# dtype: object

# %%
uni=pd.DataFrame()
uni['available']=df['available'].unique()
uni.head(5)
# Out:
#   available
# 0    online
# 1     local

# %%
df.sort_values('sales',ascending = True)
df.tail(1)
# Out:
#     ID   product  sales  type available
# 14   15  item 15   45.0   2.0    online

# %%
import matplotlib.pyplot as plt
fig=plt.figure()
plt.hist(df['sales'],bins = 5) #creating histograph
plt.title('sales distribution')
plt.xlabel('sales')
plt.ylabel('#product')
plt.show()
#DATA EXPLORATION

# %%
plt.scatter(df['sales'],df['product'])
plt.title('product sales distribution')
plt.xlabel('sales')
plt.ylabel('product')
plt.show()

#SCATTER PLOT

# %%
import seaborn as sns
sns.boxplot(df['sales'])
sns.despine()
#BOX PLOT
# Out:
# C:\Users\Jithu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
test= df.groupby(['type','available']) #TYPE(AVAILABILITY(COUNT))
test.size()
#COUNTING THE UNIQUE VALUES IN THE GROUP
# Out:
# type  available
# 1.0   local        5
#       online       2
# 2.0   local        3
#       online       4
# dtype: int64

# %%
df.isnull().sum()
#to find total number of null values in each field
# Out:
# ID           0
# product      0
# sales        3
# type         1
# available    0
# dtype: int64

# %%
from numpy import nan
df = df.replace(0,nan)
df.head(15)

#replaces null values with NAN
# Out:
#     ID   product  sales  type available
# 0     1   item 1   10.0   1.0    online
# 1     2    item2   18.0   2.0     local
# 2     3    item3    NaN   1.0     local
# 3     4   item 4   23.0   2.0    online
# 4     5   item 5   12.0   2.0     local
# 5     6   item 6   56.0   1.0    online
# 6     7   item 7   78.0   NaN    online
# 7     8   item 8   34.0   2.0    online
# 8     9   item 9   23.0   1.0     local
# 9    10  item 10   98.0   1.0     local
# 10   11  item 11    NaN   1.0     local
# 11   12  item 12   65.0   2.0     local
# 12   13  item 13   43.0   2.0    online
# 13   14  item 14    NaN   1.0     local
# 14   15  item 15   45.0   2.0    online

# %%
import numpy as np
meansales = np.mean(df.sales)
df.sales=df.sales.fillna(meansales)
df.head(15)

#replacing mean value with missing values
# Out:
#     ID   product      sales  type available
# 0     1   item 1  10.000000   1.0    online
# 1     2    item2  18.000000   2.0     local
# 2     3    item3  42.083333   1.0     local
# 3     4   item 4  23.000000   2.0    online
# 4     5   item 5  12.000000   2.0     local
# 5     6   item 6  56.000000   1.0    online
# 6     7   item 7  78.000000   NaN    online
# 7     8   item 8  34.000000   2.0    online
# 8     9   item 9  23.000000   1.0     local
# 9    10  item 10  98.000000   1.0     local
# 10   11  item 11  42.083333   1.0     local
# 11   12  item 12  65.000000   2.0     local
# 12   13  item 13  43.000000   2.0    online
# 13   14  item 14  42.083333   1.0     local
# 14   15  item 15  45.000000   2.0    online

# %%
df1 = pd.read_excel (r'C:\Users\Jithu\Downloads\salesdata.xlsx')
df2 = pd.read_excel (r'C:\Users\Jithu\Downloads\salesdata.xlsx')
df_new = pd.concat([df1,df2])
df_new

#data integration - two diff files integration (concatenation)
# Out:
#     ID   product  sales  type available
# 0     1   item 1   10.0   1.0    online
# 1     2    item2   18.0   2.0     local
# 2     3    item3    NaN   1.0     local
# 3     4   item 4   23.0   2.0    online
# 4     5   item 5   12.0   2.0     local
# 5     6   item 6   56.0   1.0    online
# 6     7   item 7   78.0   NaN    online
# 7     8   item 8   34.0   2.0    online
# 8     9   item 9   23.0   1.0     local
# 9    10  item 10   98.0   1.0     local
# 10   11  item 11    NaN   1.0     local
# 11   12  item 12   65.0   2.0     local
# 12   13  item 13   43.0   2.0    online
# 13   14  item 14    NaN   1.0     local
# 14   15  item 15   45.0   2.0    online
# 0     1   item 1   10.0   1.0    online
# 1     2    item2   18.0   2.0     local
# 2     3    item3    NaN   1.0     local
# 3     4   item 4   23.0   2.0    online
# 4     5   item 5   12.0   2.0     local
# 5     6   item 6   56.0   1.0    online
# 6     7   item 7   78.0   NaN    online
# ...
